# %%
# Datos Sinteticos
## Utilizacion de la libreria FAKER

# %%
import pandas as pd
import numpy as np
import random

# %%
from faker import Faker

# %%
pip install faker
# Out:
# Requirement already satisfied: faker in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (40.21.0)
# Requirement already satisfied: tzdata in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from faker) (2026.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Creamos una instancia faker
fake = Faker("es_MX")

# %%
# Generamos datos sintéticos o datos falsos
datos = []
for i in range(100):
    datos.append(
        {
            "id_usuario": i + 1,
            "nombre" : fake.name(),
            "correo" : fake.email(),
            "edad" : random.randint(18, 65),
            "seguidores" : random.randint(50, 5000),
            "plataforma" : random.choice(["TikTok", "Instagram", "YouTube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                               nombre  \
# 0            1                    Sr. Ramiro Curiel
# 1            2                        Abril Negrete
# 2            3                Javier Zayas Gallegos
# 3            4                            Zoé Roque
# 4            5                Clara Aparicio Espino
# ..         ...                                  ...
# 95          96  Miguel Ángel Agustín Quiñones Bravo
# 96          97                   Andrés Gómez Baeza
# 97          98                     Dulce María Loya
# 98          99                Elias Abraham Becerra
# 99         100                       Mónica Acevedo
#
#                             correo  edad  seguidores plataforma
# 0              wriojas@example.org    24        4247     TikTok
# 1   sevillaluis-miguel@example.net    61         982    YouTube
# 2      felixecheverria@example.net    56        2483    YouTube
# 3             noelia02@example.org    44        1264  Instagram
# 4               yperes@example.org    36        4458  Instagram
# ..                             ...   ...         ...        ...
# 95       valverdemitzy@example.com    29        4720     TikTok
# 96         merinoelisa@example.com    47        4335  Instagram
# 97         fierrojaime@example.org    44        2834  Instagram
# 98            bnegrete@example.net    43        4330     TikTok
# 99         oteroflavio@example.com    30        3916  Instagram
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id_usuario  100 non-null    int64
#  1   nombre      100 non-null    object
#  2   correo      100 non-null    object
#  3   edad        100 non-null    int64
#  4   seguidores  100 non-null    int64
#  5   plataforma  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   41.590000  2597.330000
# std     29.011492   13.811937  1557.137039
# min      1.000000   18.000000    88.000000
# 25%     25.750000   29.000000  1154.750000
# 50%     50.500000   43.000000  2650.000000
# 75%     75.250000   54.000000  4207.250000
# max    100.000000   65.000000  4965.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario             nombre               correo        edad  \
# count   100.000000                100                  100  100.000000
# unique         NaN                100                  100         NaN
# top            NaN  Sr. Ramiro Curiel  wriojas@example.org         NaN
# freq           NaN                  1                    1         NaN
# mean     50.500000                NaN                  NaN   41.590000
# std      29.011492                NaN                  NaN   13.811937
# min       1.000000                NaN                  NaN   18.000000
# 25%      25.750000                NaN                  NaN   29.000000
# 50%      50.500000                NaN                  NaN   43.000000
# 75%      75.250000                NaN                  NaN   54.000000
# max     100.000000                NaN                  NaN   65.000000
#
#          seguidores plataforma
# count    100.000000        100
# unique          NaN          3
# top             NaN  Instagram
# freq            NaN         43
# mean    2597.330000        NaN
# std     1557.137039        NaN
# min       88.000000        NaN
# 25%     1154.750000        NaN
# 50%     2650.000000        NaN
# 75%     4207.250000        NaN
# max     4965.000000        NaN

# %%
# Instalar las librerías de visualización directamente en el entorno
# !pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (3.10.9)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Instalar las librerías de visualización directamente en el entorno
# !pip install seaborn matplotlib
# Out:
# Requirement already satisfied: seaborn in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (0.13.2)
# Requirement already satisfied: matplotlib in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (3.10.9)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from seaborn) (2.4.4)
# Requirement already satisfied: pandas>=1.2 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from pandas>=1.2->seaborn) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\100043016\anaconda3\envs\Extraccion9AVS\Lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Graficamos la cantidad de usuarios por plataforma
plt.figure(figsize=(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()

# %%
# Graficamos la cantidad de usuarios por plataforma
plt.figure(figsize=(8,4))
sns.countplot(x="plataforma", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
